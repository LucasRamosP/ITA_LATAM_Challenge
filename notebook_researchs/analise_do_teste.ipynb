# %%
import pandas as pd

# %%
data_test = pd.read_csv('data\idsc_test.csv')
data_test.head(5)
# Out:
#                            flightid origem destino                   dt_dep
# 0  7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV  2023-05-30 11:36:03.000  \
# 1  85cb958e8b9d583575cd9cb93e389226   SBFL    SBRJ  2023-05-19 08:26:06.000
# 2  2d4e8cd3947525a12ff16af520beefb9   SBCF    SBGR  2023-05-22 11:52:02.000
# 3  24cf317a1494a016a018d9f5cd183639   SBFL    SBSP  2023-05-29 16:07:07.000
# 4  370babaf32dc82a6a64bf5b71a3434ed   SBCF    SBKP  2023-05-25 22:16:04.000
#
#                   hora_ref                                     snapshot_radar
# 0  2023-05-30 11:00:00.000  MULTIPOINT ((-0.8807200448127578 -0.5148453155...  \
# 1  2023-05-19 08:00:00.000  MULTIPOINT ((-0.8826266039383116 -0.4926305156...
# 2  2023-05-22 11:00:00.000  MULTIPOINT ((-0.8972512464147154 -0.5215196550...
# 3  2023-05-29 16:00:00.000  MULTIPOINT ((-0.892972783728755 -0.51704889771...
# 4  2023-05-25 22:00:00.000  MULTIPOINT ((-0.8970045369724385 -0.5240544927...
#
# ...
